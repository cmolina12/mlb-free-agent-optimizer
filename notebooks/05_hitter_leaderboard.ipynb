# %%
import sys, pathlib

# Find the project root (MLB-FREE-AGENT-OPTIMIZER/)
PROJECT_ROOT = pathlib.Path.cwd().parents[0]

# Add the src folder to the Python import path
sys.path.append(str(PROJECT_ROOT / "src"))

# Import from the package
from front_office.data_access import load_hitting_table

hitting = load_hitting_table()

print(hitting.columns.tolist())  # as a Python list
# or just
print(hitting.columns)
# Out:
# ['last_name, first_name', 'player_id', 'attempts', 'avg_hit_angle', 'anglesweetspotpercent', 'max_hit_speed', 'avg_hit_speed', 'ev50', 'fbld', 'gb', 'max_distance', 'avg_distance', 'avg_hr_distance', 'ev95plus', 'ev95percent', 'barrels', 'brl_percent', 'brl_pa', 'year', 'name_last', 'name_first', 'key_mlbam', 'key_retro', 'key_bbref', 'key_fangraphs', 'mlb_played_first', 'mlb_played_last', 'playerID', 'yearID', 'nameFirst', 'nameLast', 'G', 'AB', 'R', 'H', 'doubles', 'triples', 'HR', 'RBI', 'SB', 'CS', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'GIDP', 'PA', 'AVG', 'OBP', 'TB', 'SLG', 'OPS', 'HR_rate', 'BB_rate', 'K_rate', 'has_mlb_stats', 'is_rookie_or_prospect']
# Index(['last_name, first_name', 'player_id', 'attempts', 'avg_hit_angle',
#        'anglesweetspotpercent', 'max_hit_speed', 'avg_hit_speed', 'ev50',
#        'fbld', 'gb', 'max_distance', 'avg_distance', 'avg_hr_distance',
#        'ev95plus', 'ev95percent', 'barrels', 'brl_percent', 'brl_pa', 'year',
# ...
